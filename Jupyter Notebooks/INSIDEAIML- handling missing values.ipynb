# %% [markdown]
# Lifecycle of a Data Science Projects
# 1. Data Collection Statergy---from company side,3rd party APi's,Surveys,Surveys
# 2. Feature Engineering---Handling Missing Values
#
# Why are their Missing values?? Survey--Depression Survey
# 1. They hesitate to put down the information
# 2. Survey informations are not that valid
# 3. Men--salary
# 4. Women---age
# 5. People may have died----NAN
#
# Data Science Projects---Dataset should be collected from multiple sources

# %% [markdown]
# #### What are the different types of Missing Data?
#
# 1. ##### Missing Completely at Random, MCAR:
# A variable is missing completely at random (MCAR) if the probability of being missing is the same for all the observations. When data is MCAR, there is absolutely no relationship between the data missing and any other values, observed or missing, within the dataset. In other words, those missing data points are a random subset of the data. There is nothing systematic going on that makes some data more likely to be missing than other.

# %%
import pandas as pd

# %%
df=pd.read_csv("D:/My Documents/Machine Learning/DataSets/titanic/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum() #calculate how many null value in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Cabin'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# 2. ##### Missing Data Not At Random(MNAR): Systematic missing Values
# There is absolutely some relationship between the data missing and any other values, observed or missing, within the dataset.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
df['cabin_null']=np.where(df['Cabin'].isnull(),1,0) #if null put 1 else 0 

##find the percentage of null values
df['cabin_null'].mean()
# Out:
# 0.7710437710437711

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['cabin_null']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    1
# 889    0
# 890    1
# Name: cabin_null, Length: 891, dtype: int32

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'cabin_null'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age_Null'] = np.where(df['Age'].isnull(),1,0) #if null put 1 else 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age_Null'].mean()
# Out:
# 0.19865319865319866

# %%
df['Gender_male_female'] = np.where(df['Sex'] == 'male',1,0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Gender_male_female'].mean()
# Out:
# 0.6475869809203143

# %%
df['embarked_null'] = np.where(df['Embarked'].isnull(),1,0) #if null put 1

# %%
df['embarked_null'].mean()
# Out:
# 0.002244668911335578

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  cabin_null  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN           0
# 829  female  62.0      0      0  113572  80.0   B28      NaN           0
#
#      Age_Null  Gender_male_female  embarked_null
# 61          0                   0              1
# 829         0                   0              1

# %% [markdown]
# #### Missing At Random(MAR)

# %% [markdown]
# #### Mean/ MEdian /Mode imputation
# When should we apply?
# Mean/median imputation has the assumption that the data are missing completely at random(MCAR). We solve this by replacing the NAN with the most frequent occurance of the variables

# %%
df=pd.read_csv("D:/My Documents/Machine Learning/DataSets/titanic/train.csv",usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
## Lets go and see the percentage of missing values
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
def impute_nan(df,variable,med):
    df[variable+"_median"]=df[variable].fillna(med)

# %%
median=df.Age.median()
median
print("the median from Age column which is available in df dataframe is",median)
# Out:
# the median from Age column which is available in df dataframe is 28.0

# %%
impute_nan(df,'Age',median)
df.head()
# Out:
#    Survived   Age     Fare  Age_median
# 0         0  22.0   7.2500        22.0
# 1         1  38.0  71.2833        38.0
# 2         1  26.0   7.9250        26.0
# 3         1  35.0  53.1000        35.0
# 4         0  35.0   8.0500        35.0

# %%
df[df['Age'].isnull()]
# Out:
#      Survived  Age     Fare  Age_median
# 5           0  NaN   8.4583        28.0
# 17          1  NaN  13.0000        28.0
# 19          1  NaN   7.2250        28.0
# 26          0  NaN   7.2250        28.0
# 28          1  NaN   7.8792        28.0
# ..        ...  ...      ...         ...
# 859         0  NaN   7.2292        28.0
# 863         0  NaN  69.5500        28.0
# 868         0  NaN   9.5000        28.0
# 878         0  NaN   7.8958        28.0
# 888         0  NaN  23.4500        28.0
#
# [177 rows x 4 columns]

# %%
df.iloc[888] #888 index
# Out:
# Survived       0.00
# Age             NaN
# Fare          23.45
# Age_median    28.00
# Name: 888, dtype: float64

# %%
print(df['Age'].std())
print(df['Age_median'].std())
# Out:
# 14.526497332334044
# 13.019696550973194

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age_median'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Survived        0
# Age           177
# Fare            0
# Age_median      0
# dtype: int64

# %%
df
# Out:
#      Survived   Age     Fare  Age_median
# 0           0  22.0   7.2500        22.0
# 1           1  38.0  71.2833        38.0
# 2           1  26.0   7.9250        26.0
# 3           1  35.0  53.1000        35.0
# 4           0  35.0   8.0500        35.0
# ..        ...   ...      ...         ...
# 886         0  27.0  13.0000        27.0
# 887         1  19.0  30.0000        19.0
# 888         0   NaN  23.4500        28.0
# 889         1  26.0  30.0000        26.0
# 890         0  32.0   7.7500        32.0
#
# [891 rows x 4 columns]

# %%
df.drop(['Age'],inplace=True,axis = 1)

# %%
df
# Out:
#      Survived     Fare  Age_median
# 0           0   7.2500        22.0
# 1           1  71.2833        38.0
# 2           1   7.9250        26.0
# 3           1  53.1000        35.0
# 4           0   8.0500        35.0
# ..        ...      ...         ...
# 886         0  13.0000        27.0
# 887         1  30.0000        19.0
# 888         0  23.4500        28.0
# 889         1  30.0000        26.0
# 890         0   7.7500        32.0
#
# [891 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Fare          0
# Age_median    0
# dtype: int64

# %% [markdown]
# ### Advantages And Disadvantages of Mean/Median Imputation
#
# #### Advantages
# 1. Easy to implement(Robust to outliers)
# 2. Faster way to obtain the complete dataset
# #### Disadvantages
# 1. Change or Distortion in the original variance
# 2. Impacts Correlation

# %%
df
# Out:
#      Survived     Fare  Age_median
# 0           0   7.2500        22.0
# 1           1  71.2833        38.0
# 2           1   7.9250        26.0
# 3           1  53.1000        35.0
# 4           0   8.0500        35.0
# ..        ...      ...         ...
# 886         0  13.0000        27.0
# 887         1  30.0000        19.0
# 888         0  23.4500        28.0
# 889         1  30.0000        26.0
# 890         0   7.7500        32.0
#
# [891 rows x 3 columns]
